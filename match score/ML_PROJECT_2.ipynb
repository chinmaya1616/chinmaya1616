# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings(action='ignore')

# %%
ipl = pd.read_csv(r'/Users/surajsamal/Desktop/untitled folder 2/ipl_data.csv')
ipl
# Out:
#        mid        date                                      venue  \
# 0        1  2008-04-18                      M Chinnaswamy Stadium
# 1        1  2008-04-18                      M Chinnaswamy Stadium
# 2        1  2008-04-18                      M Chinnaswamy Stadium
# 3        1  2008-04-18                      M Chinnaswamy Stadium
# 4        1  2008-04-18                      M Chinnaswamy Stadium
# ...    ...         ...                                        ...
# 76009  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76010  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76011  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76012  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76013  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
#
#                     bat_team                    bowl_team      batsman  \
# 0      Kolkata Knight Riders  Royal Challengers Bangalore   SC Ganguly
# ...

# %%
# Display the column names
ipl.columns
# Out:
# Index(['mid', 'date', 'venue', 'bat_team', 'bowl_team', 'batsman', 'bowler',
#        'runs', 'wickets', 'overs', 'runs_last_5', 'wickets_last_5', 'striker',
#        'non-striker', 'total'],
#       dtype='object')

# %%
import pandas as pd

# Assuming you've already loaded the dataset into df
# For example:
# df = pd.read_csv('your_dataset.csv')

# 1. Total runs in the entire dataset
total_runs = ipl['runs'].sum()

# 2. Total runs by a specific batsman
batsman_name = 'BB McCullum'  # Replace with the batsman you're interested in
batsman_runs = ipl[ipl['batsman'] == batsman_name]['runs'].sum()

# 3. Total runs in a specific match
match_id = 1  # Replace with the match ID you're interested in
match_runs = ipl[ipl['mid'] == match_id]['runs'].sum()

# 4. Total runs in the last 5 overs (overs >= 15, assuming 20-over match)
last_5_overs_runs = ipl[ipl['overs'] >= 15]['runs'].sum()

# 5. Total runs by each batting team
team_runs = ipl.groupby('bat_team')['runs'].sum()

# Printing the results
print(f"Total runs in the dataset: {total_runs}")
print(f"Total runs scored by {batsman_name}: {batsman_runs}")
print(f"Total runs in match {match_id}: {match_runs}")
print(f"Total runs in the last 5 overs: {last_5_overs_runs}")
print("Total runs by each team:")
print(team_runs)
# Out:
# Total runs in the dataset: 5692639
# Total runs scored by BB McCullum: 62763
# Total runs in match 1: 12220
# Total runs in the last 5 overs: 2574227
# Total runs by each team:
# bat_team
# Chennai Super Kings            704009
# Deccan Chargers                389719
# Delhi Daredevils               525339
# Gujarat Lions                  136106
# Kings XI Punjab                701187
# Kochi Tuskers Kerala            63121
# Kolkata Knight Riders          587747
# Mumbai Indians                 756186
# Pune Warriors                  170963
# Rajasthan Royals               502878
# Rising Pune Supergiant          76113
# Rising Pune Supergiants         60997
# Royal Challengers Bangalore    625136
# Sunrisers Hyderabad            393138
# Name: runs, dtype: int64
